# %% [markdown]
# <a href="https://colab.research.google.com/github/zerover0/HelloPython/blob/master/%EC%BD%94%EB%94%A9%EC%9C%BC%EB%A1%9C_%EA%B3%B5%EB%B6%80%ED%95%98%EB%8A%94_%EA%B3%BC%ED%95%99_%EC%9D%B4%EC%95%BC%EA%B8%B0_1_(%EC%8B%A4%EC%8A%B5%EC%9A%A9).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !sudo apt-get install -y fonts-nanum
# !sudo fc-cache -fv
# !rm ~/.cache/matplotlib -rf
# Out:
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# The following NEW packages will be installed:
#   fonts-nanum
# 0 upgraded, 1 newly installed, 0 to remove and 6 not upgraded.
# Need to get 10.3 MB of archives.
# After this operation, 34.1 MB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu jammy/universe amd64 fonts-nanum all 20200506-1 [10.3 MB]
# Fetched 10.3 MB in 0s (45.5 MB/s)
# debconf: unable to initialize frontend: Dialog
# debconf: (No usable dialog-like program is installed, so the dialog based frontend cannot be used. at /usr/share/perl5/Debconf/FrontEnd/Dialog.pm line 78, <> line 1.)
# debconf: falling back to frontend: Readline
# debconf: unable to initialize frontend: Readline
# debconf: (This frontend requires a controlling tty.)
# debconf: falling back to frontend: Teletype
# dpkg-preconfigure: unable to re-open stdin:
# Selecting previously unselected package fonts-nanum.
# ...

# %%
total = 0
for i in range(1, 101):
    ??? += ???

print("1부터 100까지 정수의 합:", total)
# Out:
# 1부터 100까지 정수의 합: 5050

# %%
total = 0
for i in range(1, 101):
    if (??? % ???) == 0:
        ??? += ???

print("1부터 100까지 정수의 합:", total)
# Out:
# 1부터 100까지 정수의 합: 2550

# %%
# 1. 중력 가속도 변수 만들기
# 지구의 중력 가속도는 약 9.8m/s^2 입니다.
# g 라는 이름의 변수를 만들고 9.8을 저장해 보세요.
g = ???

# 2. 시간 데이터 만들기
# 0초부터 5초까지 1초 간격으로 측정한다고 가정해 봅시다.
# time_list 라는 리스트에 0, 1, 2, 3, 4, 5를 순서대로 넣어보세요.
time_list = [ ???, ???, ???, ???, ???, ??? ]

print("중력 가속도:", g)
print("시간 리스트:", time_list)
# Out:
# 중력 가속도: 9.8
# 시간 리스트: [0, 1, 2, 3, 4, 5]

# %%
# 속도와 거리를 저장할 빈 보관함을 미리 만듭니다.
velocity_list = []
distance_list = []

# for문을 이용해 시간이 0초부터 5초까지 흐를 때, 각각의 속도와 거리를 계산합니다.
for t in  ???:
    # 속도 공식: 속도 = 중력가속도 * 시간
    v = ??? * ???

    # 거리 공식: 거리 = 0.5 * 중력가속도 * 시간의 제곱
    # (파이썬에서 기호 ** 는 거듭제곱을 의미합니다)
    d = 0.5 * ??? * (??? ** 2)

    # 계산된 결과를 리스트에 하나씩 추가합니다.
    velocity_list.append(v)
    distance_list.append(d)

print("계산된 속도 데이터:", velocity_list)
print("계산된 거리 데이터:", distance_list)
# Out:
# 계산된 속도 데이터: [0.0, 9.8, 19.6, 29.400000000000002, 39.2, 49.0]
# 계산된 거리 데이터: [0.0, 4.9, 19.6, 44.1, 78.4, 122.50000000000001]

# %%
# 그래프를 그리기 위한 파이썬 도구를 불러옵니다.
import matplotlib.pyplot as plt
# plt.rc('font', family='NanumBarunGothic') # 한글글꼴 사용

# 그래프의 전체 크기를 설정합니다.
plt.figure(figsize=(10, 4))

# --- 첫 번째 그래프: 시간에 따른 속도 ---
plt.subplot(1, 2, 1) # 화면을 1행 2열로 나누고 첫 번째 칸에 그립니다.
# x축에는 시간(time_list), y축에는 속도(velocity_list)를 넣어보세요.
plt.plot( ???, ???, marker='o', color='red')
plt.title('시간 - 속도')
plt.xlabel('시간(초)')
plt.ylabel('속도(m/s)')

# --- 두 번째 그래프: 시간에 따른 낙하 거리 ---
plt.subplot(1, 2, 2) # 화면을 1행 2열로 나누고 두 번째 칸에 그립니다.
# x축에는 시간(time_list), y축에는 거리(distance_list)를 넣어보세요.
plt.plot( ???, ???, marker='o', color='blue')
plt.title('시간 - 거리')
plt.xlabel('시간(초)')
plt.ylabel('거리(m)')

# 완성된 그래프를 화면에 보여줍니다.
plt.tight_layout()
plt.show()
